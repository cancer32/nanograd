# %%
from nanograd.nn import Linear
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from nanograd.nn import Linear
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
#
# ModuleNotFoundError: No module named 'nanograd'

# %%
csv = r"dataset\couple_of_points.csv"
data = pd.read_csv(csv)
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 csv = r"dataset\couple_of_points.csv"
# ----> 2 data = pd.read_csv(csv)
#       3 data
#
# NameError: name 'pd' is not defined

# %%
model = Linear(n_inputs=1)

# %%
lr = 0.008
for _ in range(100):
    pred = [model([x]) for x in data.x]
    loss = sum((gth-ylbl)**2 for gth, ylbl in zip(pred, data.y))/len(data.y)
    loss.zero_grad()
    loss.backward()
    for p in model.parameters():
        p.data -= lr * p.grad  
print(loss)

x_ = np.linspace(0, 20, 10)
pred = [model([i]).item() for i in x_]
plt.plot(x_,pred, label=r'$x = 2y$ or $y = \frac{x}{2}$')
plt.scatter(data.x, data.y)
# Out:
# Scalar(1.4467695138628942)
